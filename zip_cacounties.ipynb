# %%
import pandas as pd
uszipcodes = pd.read_csv('/Users/susanlieu/Documents/practicum/uszips_sl.csv')
cademog = pd.read_csv('/Users/susanlieu/Documents/practicum/ca_demo.csv')

# %%
cademog.head()
# Out:
#        FIPS Geographic Identifier                Name of Area  \
# 0  Geo_FIPS             Geo_GEOID                    Geo_NAME
# 1      6001          05000US06001  Alameda County, California
# 2      6003          05000US06003   Alpine County, California
# 3      6005          05000US06005   Amador County, California
# 4      6007          05000US06007    Butte County, California
#
#               Qualifying Name State/U.S.-Abbreviation (USPS) Summary Level  \
# 0                   Geo_QName                     Geo_STUSAB    Geo_SUMLEV
# 1  Alameda County, California                             ca            50
# 2   Alpine County, California                             ca            50
# 3   Amador County, California                             ca            50
# 4    Butte County, California                             ca            50
#
#   Geographic Component File Identification Logical Record Number      US  \
# ...

# %%
uszipcodes.head()
# Out:
#      zip      lat       lng              city state_id   state_name  zcta  \
# 0    951  18.4284  -66.2566          Toa Baja       PR  Puerto Rico  True
# 1  96863  21.4484 -157.7623  Mcbh Kaneohe Bay       HI       Hawaii  True
# 2  34141  25.9723  -81.0936           Ochopee       FL      Florida  True
# 3  78060  28.4469  -98.1071          Oakville       TX        Texas  True
# 4  78144  28.9551  -97.8880       Panna Maria       TX        Texas  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN          35     32.5        72137    Toa Baja
# 1          NaN          52    708.1        15003    Honolulu
# 2          NaN         232      0.1        12021     Collier
# 3          NaN          37     36.3        48297    Live Oak
# 4          NaN          45      7.7        48255      Karnes
#
#              all_county_weights  imprecise  military             timezone
# 0                 {'72137':100}      False     False  America/Puerto_Rico
# ...

# %%
zips_filtered = pd.read_csv('/Users/susanlieu/Documents/practicum/uszips_sl.csv', usecols=['zip', 'state_name', 'county_name'])

# %%
zips_filtered.head()
# Out:
#      zip   state_name county_name
# 0    951  Puerto Rico    Toa Baja
# 1  96863       Hawaii    Honolulu
# 2  34141      Florida     Collier
# 3  78060        Texas    Live Oak
# 4  78144        Texas      Karnes

# %%
cademog_filtered = pd.read_csv('/Users/susanlieu/Documents/practicum/ca_demo.csv', usecols=['Name of Area',
                                                                                            'Population 25 Years and Over:',
                                                                                            'Population 25 Years and Over: Less than High School',
                                                                                            'Population 25 Years and Over: High School Graduate (Includes Equivalency)',
                                                                                            'Population 25 Years and Over: Some College',
                                                                                            'Population 25 Years and Over: Bachelor\'s Degree',
                                                                                            'Population 25 Years and Over: Master\'s Degree',
                                                                                            'Population 25 Years and Over: Professional School Degree',
                                                                                            'Population 25 Years and Over: Doctorate Degree',
                                                                                            '% Population 25 Years and Over: Less than High School',
                                                                                            '% Population 25 Years and Over: High School Graduate (Includes Equivalency)',
                                                                                            '% Population 25 Years and Over: Some College',
                                                                                            '% Population 25 Years and Over: Bachelor\'s Degree',
                                                                                            '% Population 25 Years and Over: Master\'s Degree',
                                                                                            '% Population 25 Years and Over: Professional School Degree',
                                                                                            '% Population 25 Years and Over: Doctorate Degree',
                                                                                            'Civilian Population 16 to 19 Years:',
                                                                                            'Civilian Population 16 to 19 Years: Not High School Graduate, Not Enrolled (Dropped Out)',
                                                                                            'Civilian Population 16 to 19 Years: High School Graduate, or Enrolled (in School)',
                                                                                            '% Civilian Population 16 to 19 Years: Not High School Graduate, Not Enrolled (Dropped Out)',
                                                                                            '% Civilian Population 16 to 19 Years: High School Graduate, or Enrolled (in School)', 
                                                                                            'Median Household Income (In 2017 Inflation Adjusted Dollars)', 
                                                                                            'Population Under 18 Years of Age for Whom Poverty Status Is Determined:',
                                                                                            'Population Under 18 Years of Age for Whom Poverty Status Is Determined: Living in Poverty', 
                                                                                            'Population Under 18 Years of Age for Whom Poverty Status Is Determined: At or Above Poverty Level',
                                                                                            '% Population Under 18 Years of Age for Whom Poverty Status Is Determined: Living in Poverty',
                                                                                            '% Population Under 18 Years of Age for Whom Poverty Status Is Determined: At or Above Poverty Level',
                                                                                            'Households','Households with Housing Costs more than 30% of Income', 
                                                                                            '% Households with Housing Costs more than 30% of Income'
                                                                                        ])

# %%
cademog_filtered.head()
# Out:
#                  Name of Area Population 25 Years and Over:  \
# 0                    Geo_NAME                   SE_T025_001
# 1  Alameda County, California                       1139149
# 2   Alpine County, California                           811
# 3   Amador County, California                         28953
# 4    Butte County, California                        145918
#
#   Population 25 Years and Over: Less than High School  \
# 0                                        SE_T025_002
# 1                                             141961
# 2                                                 83
# 3                                               2978
# 4                                              16411
#
#   Population 25 Years and Over: High School Graduate (Includes Equivalency)  \
# 0                                        SE_T025_003
# 1                                             203796
# 2                                                277
# ...

# %%
zips_filtered.shape
# Out:
# (33099, 3)

# %%
cademog_filtered.shape
# Out:
# (59, 30)

# %%
zips_caonly = zips_filtered[(zips_filtered['state_name'] == 'California')]

# %%
zips_caonly.head()
# Out:
#       zip  state_name     county_name
# 23  92280  California  San Bernardino
# 25  92304  California  San Bernardino
# 27  92332  California  San Bernardino
# 30  93519  California            Kern
# 48  95226  California       Calaveras

# %%
zips_caonly.shape
# Out:
# (1761, 3)

# %%
zips_ca = zips_caonly[['zip', 'county_name']]

# %%
zips_ca.head() #new dataset with zips in one cell separated by ; keep county_name as separate column in different jupyter notebook
# Out:
#       zip     county_name
# 23  92280  San Bernardino
# 25  92304  San Bernardino
# 27  92332  San Bernardino
# 30  93519            Kern
# 48  95226       Calaveras

# %%
zips_ca.shape
# Out:
# (1761, 2)

# %%
# remove "County, California" from cademog.filtered df
import re

cademog_filtered['Name of Area'] = cademog_filtered['Name of Area'].apply(lambda x: 
                                                                         re.sub(r'(\sCounty\,\sCalifornia)','', x))
cademog_filtered
# Out:
#        Name of Area Population 25 Years and Over:  \
# 0          Geo_NAME                   SE_T025_001
# 1           Alameda                       1139149
# 2            Alpine                           811
# 3            Amador                         28953
# 4             Butte                        145918
# 5         Calaveras                         34250
# 6            Colusa                         13509
# 7      Contra Costa                        767132
# 8         Del Norte                         19424
# 9         El Dorado                        132744
# 10           Fresno                        588491
# 11            Glenn                         17927
# 12         Humboldt                         91359
# 13         Imperial                        108522
# 14             Inyo                         13230
# 15             Kern                        526286
# 16            Kings                         91889
# 17             Lake                         46386
# ...

# %%
# change "Name of Area" to "county_name"

cademog_filtered = cademog_filtered.rename({'Name of Area':'county_name'}, axis='columns')

# %%
cademog_filtered.drop(cademog_filtered.index[0])
# Out:
#         county_name Population 25 Years and Over:  \
# 1           Alameda                       1139149
# 2            Alpine                           811
# 3            Amador                         28953
# 4             Butte                        145918
# 5         Calaveras                         34250
# 6            Colusa                         13509
# 7      Contra Costa                        767132
# 8         Del Norte                         19424
# 9         El Dorado                        132744
# 10           Fresno                        588491
# 11            Glenn                         17927
# 12         Humboldt                         91359
# 13         Imperial                        108522
# 14             Inyo                         13230
# 15             Kern                        526286
# 16            Kings                         91889
# 17             Lake                         46386
# 18           Lassen                         22422
# ...

# %%
# tbd - import zips dictionary
for county_key in cademog_filtered['county_name']:
    print (county_key)
    # zips[county_key]
    # df = df.append({'A': i}, ignore_index=True)
    cademog_filtered = cademog_filtered.append({'zip' : zips[county_key]}, ignore_index=True)
# Out:
# Geo_NAME
# Alameda
# Alpine
# Amador
# Butte
# Calaveras
# Colusa
# Contra Costa
# Del Norte
# El Dorado
# Fresno
# Glenn
# Humboldt
# Imperial
# Inyo
# Kern
# Kings
# Lake
# Lassen
# Los Angeles
# Madera
# Marin
# Mariposa
# Mendocino
# Merced
# Modoc
# Mono
# Monterey
# Napa
# Nevada
# Orange
# Placer
# Plumas
# Riverside
# Sacramento
# San Benito
# San Bernardino
# San Diego
# San Francisco
# San Joaquin
# San Luis Obispo
# San Mateo
# Santa Barbara
# Santa Clara
# Santa Cruz
# Shasta
# Sierra
# Siskiyou
# Solano
# Sonoma
# Stanislaus
# Sutter
# Tehama
# Trinity
# Tulare
# Tuolumne
# Ventura
# Yolo
# Yuba

# %%
# merge zip codes to cademog_filtered
#zips_cademog = pd.merge(zips_ca, cademog_filtered, on='county_name')

# %%
print(zips_cademog)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0f2085401d62> in <module>()
# ----> 1 print(zips_cademog)
#
# NameError: name 'zips_cademog' is not defined

# %%
zips_cademog.shape

# %%
zips_cademog.to_csv(r'/Users/susanlieu/Documents/practicum/zips_cademog.csv')

# %%
print(zips_cademog)

# %%
print()
