# %%
import pandas as pd
import numpy as np

# %%
all_gpa = pd.read_csv('/Users/susanlieu/Documents/LIS590OMO/Data/UC/all_gpa.csv')

# %%
all_gpa.head()
# Out:
#                            Calculation1          Campus            City  \
# 0  GERMAN SWISS INTERNATIONAL SCH670905        Berkeley             NaN
# 1             AQUINAS HIGH SCHOOL052772       Riverside  San Bernardino
# 2      DESIGN SCIENCE HIGH SCHOOL054003     Los Angeles          Fresno
# 3    BLOOMFIELD HILLS HIGH SCHOOL232447  Universitywide  Bloomfield Twp
# 4          A B MILLER HIGH SCHOOL050944   Santa Barbara         Fontana
#
#   County/State/Country  Fall Term     Level                          School  \
# 0            HONG KONG       2012  Freshman  GERMAN SWISS INTERNATIONAL SCH
# 1       San Bernardino       1995  Freshman             AQUINAS HIGH SCHOOL
# 2               Fresno       2012  Freshman      DESIGN SCIENCE HIGH SCHOOL
# 3             Michigan       2015  Freshman    BLOOMFIELD HILLS HIGH SCHOOL
# 4       San Bernardino       1998  Freshman          A B MILLER HIGH SCHOOL
#
#    Adm GPA (SUM)  App GPA (SUM)  Enrl GPA (SUM)
# ...

# %%
all_gpa.shape
# Out:
# (65499, 10)

# %%
filter_gpa = pd.read_csv('/Users/susanlieu/Documents/LIS590OMO/Data/UC/all_gpa.csv', usecols=['Campus', 
                                                                                              'County/State/Country',
                                                                                              'Fall Term', 
                                                                                              'School', 
                                                                                              'App GPA (SUM)'])

# %%
filter_gpa.shape
# Out:
# (65499, 5)

# %%
filter_gpa.head()
# Out:
#            Campus County/State/Country  Fall Term  \
# 0        Berkeley            HONG KONG       2012
# 1       Riverside       San Bernardino       1995
# 2     Los Angeles               Fresno       2012
# 3  Universitywide             Michigan       2015
# 4   Santa Barbara       San Bernardino       1998
#
#                            School  App GPA (SUM)
# 0  GERMAN SWISS INTERNATIONAL SCH       3.604000
# 1             AQUINAS HIGH SCHOOL       3.361429
# 2      DESIGN SCIENCE HIGH SCHOOL       3.818000
# 3    BLOOMFIELD HILLS HIGH SCHOOL       3.950000
# 4          A B MILLER HIGH SCHOOL       3.518571

# %%
type(filter_gpa["Fall Term"])
# Out:
# pandas.core.series.Series

# %%
filter_gpa = filter_gpa[filter_gpa["Fall Term"].isin(["2017"])]

# %%
filter_gpa.head()
# Out:
#             Campus     County/State/Country  Fall Term  \
# 11        Berkeley                 Arkansas       2017
# 28  Universitywide                     Guam       2017
# 32           Davis  CHINA, PEOPLES REPUBLIC       2017
# 40     Los Angeles                 Virginia       2017
# 48  Universitywide                   CANADA       2017
#
#                          School  App GPA (SUM)
# 11      BENTONVILLE HIGH SCHOOL       4.001250
# 28  ACADEMY OF OUR LADY OF GUAM       3.863333
# 32     NANJING NO 1 HIGH SCHOOL       3.938333
# 40        CHANTILLY HIGH SCHOOL       3.840909
# 48               RIDLEY COLLEGE       3.963333

# %%
filter_gpa = filter_gpa[filter_gpa['County/State/Country'].isin(['Alameda',
                                                                        'Alpine',
                                                                        'Amador',
                                                                        'Butte',
                                                                        'Calaveras',
                                                                        'Colusa',
                                                                        'Contra Costa',
                                                                        'Del Norte',
                                                                        'El Dorado',
                                                                        'Fresno',
                                                                        'Glenn',
                                                                        'Humboldt',
                                                                        'Imperial',
                                                                        'Inyo',
                                                                        'Kern',
                                                                        'Kings',
                                                                        'Lake',
                                                                        'Lassen',
                                                                        'Los Angeles',
                                                                        'Madera',
                                                                        'Marin',
                                                                        'Mariposa',
                                                                        'Mendocino',
                                                                        'Merced',
                                                                        'Modoc',
                                                                        'Mono',
                                                                        'Monterey',
                                                                        'Napa',
                                                                        'Nevada',
                                                                        'Orange',
                                                                        'Placer',
                                                                        'Plumas',
                                                                        'Riverside',
                                                                        'Sacramento',
                                                                        'San Benito',
                                                                        'San Bernardino',
                                                                        'San Diego',
                                                                        'San Francisco',
                                                                        'San Joaquin',
                                                                        'San Luis Obispo',
                                                                        'San Mateo',
                                                                        'Santa Barbara',
                                                                        'Santa Clara',
                                                                        'Santa Cruz',
                                                                        'Shasta',
                                                                        'Sierra',
                                                                        'Siskiyou',
                                                                        'Solano',
                                                                        'Sonoma',
                                                                        'Stanislaus',
                                                                        'Sutter',
                                                                        'Tehama',
                                                                        'Trinity',
                                                                        'Tulare',
                                                                        'Tuolumne',
                                                                        'Ventura',
                                                                        'Yolo',
                                                                        'Yuba'])]

# %%
filter_gpa.head()
# Out:
#           Campus County/State/Country  Fall Term  \
# 51    Santa Cruz          Los Angeles       2017
# 53   Los Angeles          Los Angeles       2017
# 68    Santa Cruz          Los Angeles       2017
# 90        Merced           Sacramento       2017
# 100    San Diego          Los Angeles       2017
#
#                              School  App GPA (SUM)
# 51   ALLIANCE PATTI & PETER ACADEMY       3.528000
# 53    ACADEMY SCIENCE & ENGINEERING       3.905333
# 68              PIONEER HIGH SCHOOL       3.626800
# 90         CRISTO REY HS-SACRAMENTO       3.112222
# 100      ANIMO PAT BROWN CHARTER HS       3.564333

# %%
filter_gpa.shape
# Out:
# (3186, 5)

# %%
filter_gpa = filter_gpa.rename({'County/State/Country':'County','Calculation1':'High School', 'Campus':'UC_Campus'}, axis='columns')

# %%
filter_gpa.head()
# Out:
#        UC_Campus       County  Fall Term                          School  \
# 51    Santa Cruz  Los Angeles       2017  ALLIANCE PATTI & PETER ACADEMY
# 53   Los Angeles  Los Angeles       2017   ACADEMY SCIENCE & ENGINEERING
# 68    Santa Cruz  Los Angeles       2017             PIONEER HIGH SCHOOL
# 90        Merced   Sacramento       2017        CRISTO REY HS-SACRAMENTO
# 100    San Diego  Los Angeles       2017      ANIMO PAT BROWN CHARTER HS
#
#      App GPA (SUM)
# 51        3.528000
# 53        3.905333
# 68        3.626800
# 90        3.112222
# 100       3.564333

# %%
#app_White = app_only.sort_values(["County/State/ Territory","White"]).groupby("County/State/ Territory").agg({"White":sum})
#app_White.reset_index(level=0, inplace=True)

filter_gpa = filter_gpa.sort_values(['UC_Campus','County']).groupby('County').mean()
filter_gpa.reset_index(level=0, inplace=True)

filter_gpa = filter_gpa.rename(columns ={"App GPA (SUM)":"App_GPA(avg)"})

# %%
#UC_demograph = UC_demograph.drop(UC_demograph.columns[[0, -8]], axis=1) 
filter_gpa = filter_gpa.drop(filter_gpa.columns[[1]], axis=1)
filter_gpa
# Out:
#              County  App_GPA(avg)
# 0           Alameda      3.735009
# 1            Amador      3.950981
# 2             Butte      3.848226
# 3         Calaveras      3.805643
# 4            Colusa      3.831222
# 5      Contra Costa      3.735699
# 6         Del Norte      3.879167
# 7         El Dorado      3.641072
# 8            Fresno      3.731559
# 9             Glenn      3.753333
# 10         Humboldt      3.938209
# 11         Imperial      3.795303
# 12             Inyo      3.732381
# 13             Kern      3.708173
# 14            Kings      3.780983
# 15             Lake      3.760490
# 16      Los Angeles      3.609467
# 17           Madera      3.829985
# 18            Marin      3.865142
# 19         Mariposa      4.004000
# 20        Mendocino      3.904879
# 21           Merced      3.725597
# 22         Monterey      3.667499
# 23             Napa      3.823169
# 24           Nevada      3.777176
# 25           Orange      3.702305
# ...

# %%
filter_gpa.to_csv(r"/Users/susanlieu/Documents/LIS590OMO/Data/gpa.csv", sep=",", encoding="utf-8")
